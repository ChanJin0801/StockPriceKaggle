# %%
import pandas as pd
df = pd.read_csv('./data/LG_newsSocPoli.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'label', '('title', 0)', '('title', 1)',
#        '('title', 2)', '('title', 3)', '('title', 4)', '('title', 5)',
#        '('title', 6)', '('title', 7)', '('title', 8)', '('title', 9)',
#        '('title', 10)', '('title', 11)', '('title', 12)', '('title', 13)',
#        '('title', 14)', '('title', 15)', '('title', 16)', '('title', 17)',
#        '('title', 18)', '('title', 19)', '('title', 20)', '('title', 21)',
#        '('title', 22)', '('title', 23)', '('title', 24)', '('title', 25)',
#        '('title', 26)', '('title', 27)', '('title', 28)', '('title', 29)',
#        '('title', 30)', '('title', 31)', '('title', 32)', '('title', 33)',
#        '('title', 34)', '('title', 35)', '('title', 36)', '('title', 37)',
#        '('title', 38)', '('title', 39)'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
df.shape
# Out:
# (1206, 42)

# %%
df = df.reset_index(drop=True)

# %%
df.tail()
# Out:
#             date  label                        ('title', 0)  \
# 1201  2019-11-25    1.0  黃 만난 홍준표 “봄·여름·가을보다 겨울 단식이 몇배 힘들어”
# 1202  2019-11-26    0.0      인천 중구보건소 감염병관리 콘퍼런스 보건복지부장관 표창
# 1203  2019-11-27    1.0                 동해시 가수 수와진 홍보대사 위촉식
# 1204  2019-11-28    0.0    한국당 친문게이트 3대의혹 쟁점화…키워드 돈·유착·선거종합
# 1205  2019-11-29    0.0        창원시·창원힘찬병원 사회공헌사업 경과보고 및 간담회
#
#                        ('title', 1)                            ('title', 2)  \
# 1201              동북아 국제친선 탁구대회 개회식       황교안 찾아간 홍준표 “공수처법은 타협하고 선거법 막아내자”
# 1202  단독경찰 김기현 비위수사 때 수사 상황 청와대에 보고      내연녀 살해한 뒤 시신 암매장 혐의 40대 남성 구속영장 신청
# 1203         태백시 청년정책 토론회 ‘태청공감’ 개최           그래픽 유재수 전 부시장 감찰무마 의혹 관련 일지종합
# 1204   지소미아 종료 유예 6일만에 한일 과장급 대화 시작  오마이포토 황교안 떠난 자리에 정미경신보라 지지자들 쾌유기원 통성기도
# 1205   ‘군부대 휴대전화 불법 감청’ 기무사 전 중령 구속         유시민 대검이 정치인 관련 비리 모으고 있다는 첩보 입수
#
#                       ('title', 3)                    ('title', 4)  \
# 1201  조은누리양 은인 장학금까지 쾌척…불굴의 의지 보여줘        지소미아 진실공방...사과받아 vs 사실무근
# ...

# %%
for i in range(df['label'].size):
    if df['label'][i] > 0:
        df['label'][i] = 1
    if df['label'][i] < 0:
        df['label'][i] = 0
# Out:
# /Users/parkchanjin/PycharmProjects/ml-work/venv/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/parkchanjin/PycharmProjects/ml-work/venv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head()
# Out:
#          date  label                   ('title', 0)              ('title', 1)  \
# 0  2015-01-02    0.0  한국 긴급구호대 1명 에볼라 노출 가능성…독일로 후송      거리로 쫓겨난 애연가…4월부터 과태료
# 1  2015-01-05    0.0    고성까지 터져나온 새누리당 계파 갈등…갈수록 악화   조현아 혼거실 수용 “방 바꿀 계획 없다”
# 2  2015-01-06    0.0        靑 “몇 사람이 사심 갖고 나라 뒤흔들어”  옛 통진당 의원 지위 확인 소송…승소 가능성
# 3  2015-01-07    0.0     3위는 누구 손 잡을까…새정치 전대 단일화 변수     새정치연합 컷오프 순위 왜 발표 안했나
# 4  2015-01-08    1.0           육군 제7보병사단 지휘관 워크숍 가져      육군 제7보병사단 지휘관 워크숍 가져
#
#                         ('title', 2)                ('title', 3)  \
# 0           “어려운 이웃에게…” 쌀 가로챈 전과 75범    군 관사 신축 뒷돈 수주...대보 임원 구속
# 1   백화점 모녀 논란 경찰 당시 CCTV 확보 사실 관계 확인       표적파면된 해경간부 1년2개월만에 무죄
# 2  미 하원 9일 키스톤XL 법안 표결…오바마 거부권 행사 주목  단독새누리 이만우 통진당 법안 15건 공동 발의
# 3         박 대통령 12일 신년기자회견…3년차 구상 발표  이명박 측근들과 신년 만찬…모임 이어가면 좋겠다
# 4                  강릉단신강릉경찰 청소년 선도 外        육군 제7보병사단 지휘관 워크숍 가져
#
#                               ('title', 4)                      ('title', 5)  \
# ...

# %%
train = df[df['date'] < '20190101']
test = df[df['date'] > '20181231']

# %%
train.shape
# Out:
# (1206, 42)

# %%
test.shape
# Out:
# (225, 42)
